# %% [markdown]
# # Assignment 06

# %% [markdown]
# ## 01
#
# 01) 7,17,70 -> 3개
# 02) 2^{4-1} = 2^3 = 8(개)
# 03) 전체 노드 수: 2^4 - 1 = 15 / 리프 노드 수: 2^{4-1} = 8 / 내부 노드 수: 15 - 8 = 7 / 따라서 차이는 8 - 7 = 1(개)
# 04) 성립한다. 2^{h-1} - (2^{h-1} - 1) = 1 / 즉, 항상 리프 노드 수가 내부 노드 수보다 1개 많다.

# %% [markdown]
# ## 02
#
# 01) [n/2] / 완전 이진 트리에서는 마지막 레벨을 제외한 위쪽은 꽉 차있으므로, 리프 노드 수는 이 공식으로 구할 수 있다.
# 02) 내부 노드 수를 I, 리프 노드 수를 L이라고 하면, 완전 이진 트리에서는 보통 총 노드 수가 홀수이면: L = I + 1 / 총 노드 수가 짝수이면: L = I 이다.

# %% [markdown]
# ## 03
#
# 01) 5 -> 3 -> 1 -> 8 -> 7 -> 6 -> 9
# 02) 1 -> 3 -> 5 -> 6 -> 7 -> 8 -> 9
# 03) 1 -> 3 -> 6 -> 7 -> 9 -> 8 -> 5
# 04) 정리(Theorem): 이진 검색 트리 T의 중위 순회는 노드들을 정렬된 순서로 방문한다.
#
# <증명>
# 베이스 케이스: h = 1 (h: height)
# 트리는 하나의 노드(루트)만 가진다.
# 이 경우 하나의 원소만 존재하므로, 중위 순회 결과는 항상 정렬된 상태이다.
#
# 귀납적 가정:
# 높이가 k < h 인 모든 이진 검색 트리에 대해, 중위 순회는 정렬된 순서로 방문한다고 가정한다.
#
# 귀납적 전개:
# 높이가 h인 이진 검색 트리 T를 생각하자.
# 이 트리는 루트 r, 왼쪽 서브트리 T_L, 오른쪽 서브트리 T_R로 구성된다.
#
# 이진 검색 트리의 성질에 의해
# T_L의 모든 키는 r보다 작고,
# T_R의 모든 키는 r보다 크다.
#
# 귀납적 가정에 의해
# T_L과 T_R의 중위 순회 결과는 각각 정렬되어 있다.
#
# 중위 순회는 T_L → r → T_R 순서로 방문하므로,
# 전체 방문 순서는 정렬된 순서가 된다.
#
# 따라서 높이가 h인 경우에도 성립한다.
#
# 결론적으로 모든 이진 검색 트리에 대해 중위 순회는 항상 정렬된 순서를 따른다.

# %% [markdown]
# ## 04
#
# 루트 55에서 시작한다 -> 찾는 값 30은 55보다 작으므로 왼쪽 자식 15로 이동한다 -> 30은 15보다 크므로 오른쪽 자식 28로 이동한다 -> 30은 28보다 크므로 오른쪽 자식 30으로 이동한다 -> 현재 노드가 30이므로 검색 성공 / 즉, 방문 순서는 55 -> 15 -> 28 -> 30

# %% [markdown]
# ## 05
#
# 16 < 55 → 왼쪽 / 16 > 15 → 오른쪽 / 16 < 28 → 왼쪽 / 16 < 18 → 왼쪽 / 따라서 18의 왼쪽 자식으로 삽입된다.
#
# ```text
#           55
#          /  \
#        15    60
#       / \      \
#      8  28      90
#     /   / \
#    3   18 30
#       /     \
#      16      48
# ```

# %% [markdown]
# ## 06
#
# 노드 38은 자식이 하나(왼쪽 자식 33)인 노드이다. 따라서 삭제할 때 부모 48이 38 대신 33을 바로 연결하면 된다.
#
# ```text
#             55
#            /  \
#          15    60
#         / \      \
#        8  28      90
#       /     \
#      3      48
#            /  \
#           33   50
#          / \
#         32 36
# ```

# %% [markdown]
# ## 07
#
# 노드 3은 리프 노드이므로 그냥 삭제하면 된다.
#
# ```text
#             55
#            /  \
#          15    60
#         / \      \
#        8  28      90
#             \
#             48
#            /  \
#           38   50
#          /
#         33
#        / \
#       32 36
# ```

# %% [markdown]
# ## 08
#
# 15의 오른쪽 서브트리에서 가장 작은 값은 28이다. 그래서 15 자리에 28을 올리고, 원래 있던 28은 삭제한다. 원래 28은 오른쪽 자식 48만 있었으므로, 그 자리를 48이 이어받습니다. (15의 왼쪽 서브 트리 최대값인 8이 올라갈 수도 있다.)
#
# ```text
#             55
#            /  \
#          28    60
#         /  \     \
#        8   48     90
#       /   /  \
#      3   38   50
#         /
#        33
#       / \
#      32 36
# ```

# %% [markdown]
# ## 09
#
# 최대 높이는 트리가 한쪽으로만 치우친 경우이며, 루트를 높이 1로 볼 때 n개의 노드가 일렬로 연결된 형태가 된다. 따라서 최대 높이는 n이다. 최소 높이는 트리가 균형을 이룰 때이며, 루트를 높이 1로 볼 경우 ⌈log₂(n+1)⌉로 나타낼 수 있다.
#
# 최대 높이: n / 최소 높이: log₂(n+1)
